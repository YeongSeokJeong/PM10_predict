413,2013042414,2013042415,2013042416,2013042417,2013051416,2013051417,2013051418,2013051419,2013052010,2013052011,2013052012,2013052013,2013052014,2013052015,2013052016,2013052017,2013052018,2013052019,2013052020,2013052021,2013052022,2013052023,2013052024,2013052101,2013052102,2013052103,2013052104,2013052105,2013052106,2013052107,2013052108,2013052109,2013052110,2013052111,2013053015,2013061113,2013061114,2013061403,2013061404,2013062413,2013070411,2013070412,2013070912,2013072317,2013072318,2013081311,2013081312,2013082711,2013091016,2013091017,2013091018,2013092415,2013092416,2013100812,2013100813,2013100814,2013102217,2013110413,2013110414,2013111215,2013111216,2013111612,2013112613,2013112614,2013121811,2013121812,2013121813,2013121814]

# %%
import os
dr = os.listdir("./2010")
chuncheon = pd.DataFrame(columns=['지역', '측정소명', '측정소코드', '측정일시', 'SO2', 'CO', 'O3', 'NO2', 'PM10', '주소'])
for file_name in dr:
    file_name = './2010/' + file_name
    data = pd.read_excel(file_name)
    for i,step_data in data.iterrows():
        if step_data["주소"] == "강원 춘천시 석사동" and step_data["측정일시"] in error_data:
            chuncheon = chuncheon.append(step_data)
display(chuncheon)
chuncheon.to_excel("./미세먼지 참조(석사)/2010미세먼지.xlsx")
# Out:
#             지역 측정소명   측정소코드        측정일시      SO2     CO       O3      NO2  \
# 229716  강원 춘천시  석사동  132113  2010030413    0.003    0.6    0.030    0.014
# 229717  강원 춘천시  석사동  132113  2010030414    0.002    0.6    0.029    0.017
# 229718  강원 춘천시  석사동  132113  2010030415 -999.000 -999.0 -999.000 -999.000
# 229719  강원 춘천시  석사동  132113  2010030416 -999.000 -999.0 -999.000 -999.000
# 229720  강원 춘천시  석사동  132113  2010030417 -999.000 -999.0 -999.000 -999.000
# ...        ...  ...     ...         ...      ...    ...      ...      ...
# 234514  강원 춘천시  석사동  132113  2010122012    0.004    2.0    0.002    0.044
# 234515  강원 춘천시  석사동  132113  2010122013    0.004    1.8    0.003    0.044
# 234516  강원 춘천시  석사동  132113  2010122014    0.006    2.0    0.003    0.050
# 234517  강원 춘천시  석사동  132113  2010122015    0.009    2.7    0.003    0.068
# 234757  강원 춘천시  석사동  132113  2010123015    0.006    0.6    0.030    0.011
#
#        PM10          주소
# 229716   46  강원 춘천시 석사동
# 229717   37  강원 춘천시 석사동
# ...

# %%
import os
dr = os.listdir("./2011")
chuncheon = pd.DataFrame(columns=['지역', '측정소명', '측정소코드', '측정일시', 'SO2', 'CO', 'O3', 'NO2', 'PM10', '주소'])
for file_name in dr:
    file_name = './2011/' + file_name
    data = pd.read_excel(file_name)
    for i,step_data in data.iterrows():
        if step_data["주소"] == "강원 춘천시 석사동" and step_data["측정일시"] in error_data:
            chuncheon = chuncheon.append(step_data)
display(chuncheon)
chuncheon.to_excel("./미세먼지 참조(석사)/2011미세먼지.xlsx")
# Out:
#             지역 측정소명   측정소코드        측정일시      SO2     CO       O3      NO2  \
# 234460  강원 춘천시  석사동  132113  2011010613    0.006    0.6    0.029    0.019
# 234461  강원 춘천시  석사동  132113  2011010614    0.005    0.4    0.034    0.012
# 234462  강원 춘천시  석사동  132113  2011010615    0.005    0.4    0.036    0.010
# 234463  강원 춘천시  석사동  132113  2011010616    0.005    0.4    0.036    0.014
# 234472  강원 춘천시  석사동  132113  2011010701 -999.000 -999.0 -999.000 -999.000
# ...        ...  ...     ...         ...      ...    ...      ...      ...
# 249804  강원 춘천시  석사동  132113  2011081213    0.001    0.2    0.029    0.008
# 250667  강원 춘천시  석사동  132113  2011111812    0.003    0.7    0.005    0.011
# 250690  강원 춘천시  석사동  132113  2011111911    0.003    1.0    0.005    0.016
# 251507  강원 춘천시  석사동  132113  2011122312    0.005    0.4    0.021    0.013
# 251603  강원 춘천시  석사동  132113  2011122712    0.007    0.7    0.017    0.029
#
#         PM10          주소
# 234460    56  강원 춘천시 석사동
# 234461    52  강원 춘천시 석사동
# ...

# %%
import os
dr = os.listdir("./2012")
chuncheon = pd.DataFrame(columns=['지역', '측정소명', '측정소코드', '측정일시', 'SO2', 'CO', 'O3', 'NO2', 'PM10', '주소'])
for file_name in dr:
    file_name = './2012/' + file_name
    data = pd.read_excel(file_name)
    for i,step_data in data.iterrows():
        if step_data["주소"] == "강원 춘천시 석사동" and step_data["측정일시"] in error_data:
            chuncheon = chuncheon.append(step_data)
display(chuncheon)
chuncheon.to_excel("./미세먼지 참조(석사)/2012미세먼지.xlsx")
# Out:
#             지역 측정소명   측정소코드        측정일시    SO2   CO     O3    NO2 PM10  \
# 247261  강원 춘천시  석사동  132113  2012012014  0.005  0.6  0.035  0.007   20
# 247502  강원 춘천시  석사동  132113  2012013015  0.005  0.4  0.030  0.012   39
# 247559  강원 춘천시  석사동  132113  2012020124  0.005  0.5  0.029  0.013   43
# 247560  강원 춘천시  석사동  132113  2012020201  0.005  0.7  0.026  0.014   41
# 247561  강원 춘천시  석사동  132113  2012020202  0.005  0.7  0.024  0.013   51
# ...        ...  ...     ...         ...    ...  ...    ...    ...  ...
# 253426  강원 춘천시  석사동  132113  2012121111  0.007  0.9  0.009  0.022   76
# 253427  강원 춘천시  석사동  132113  2012121112  0.008  0.7  0.014  0.018   78
# 253428  강원 춘천시  석사동  132113  2012121113  0.007  0.7  0.015  0.020   65
# 253786  강원 춘천시  석사동  132113  2012122611  0.006  0.8  0.011  0.025   83
# 253787  강원 춘천시  석사동  132113  2012122612  0.007  0.6  0.017  0.018   53
#
#                 주소
# 247261  강원 춘천시 석사동
# 247502  강원 춘천시 석사동
# 247559  강원 춘천시 석사동
# 247560  강원 춘천시 석사동
# ...

# %%
import os
dr = os.listdir("./2013")
chuncheon = pd.DataFrame(columns=['지역', '측정소명', '측정소코드', '측정일시', 'SO2', 'CO', 'O3', 'NO2', 'PM10', '주소'])
for file_name in dr:
    file_name = './2013/' + file_name
    data = pd.read_excel(file_name)
    for i,step_data in data.iterrows():
        if step_data["주소"] == "강원 춘천시 석사동" and step_data["측정일시"] in error_data:
            chuncheon = chuncheon.append(step_data)
display(chuncheon)
chuncheon.to_excel("./미세먼지 참조(석사)/2013미세먼지.xlsx")
# Out:
#             지역 측정소명   측정소코드        측정일시      SO2     CO       O3      NO2  \
# 247810  강원 춘천시  석사동  132113  2013010711    0.010    2.2    0.006    0.053
# 247811  강원 춘천시  석사동  132113  2013010712    0.010    1.7    0.011    0.045
# 248051  강원 춘천시  석사동  132113  2013011712    0.009    1.0    0.023    0.029
# 248146  강원 춘천시  석사동  132113  2013012111    0.010    1.6    0.004    0.044
# 248147  강원 춘천시  석사동  132113  2013012112    0.010    1.8    0.006    0.041
# ...        ...  ...     ...         ...      ...    ...      ...      ...
# 257485  강원 춘천시  석사동  132113  2013112614    0.006    0.2    0.025    0.018
# 258010  강원 춘천시  석사동  132113  2013121811    0.012    1.3    0.016    0.046
# 258011  강원 춘천시  석사동  132113  2013121812    0.009    0.8    0.014    0.029
# 258012  강원 춘천시  석사동  132113  2013121813 -999.000 -999.0 -999.000 -999.000
# 258013  강원 춘천시  석사동  132113  2013121814 -999.000 -999.0 -999.000 -999.000
#
#         PM10          주소
# 247810   112  강원 춘천시 석사동
# 247811   125  강원 춘천시 석사동
# ...

# %%
import os
dr = os.listdir("./2011")
chuncheon = pd.DataFrame(columns=['지역', '측정소명', '측정소코드', '측정일시', 'SO2', 'CO', 'O3', 'NO2', 'PM10', '주소'])
chuncheon.columns = data.columns
for file_name in dr:
    file_name = './2011/' + file_name
    data = pd.read_excel(file_name)
    step_chuncheon_data = data[data["주소"] == '강원 춘천시 중앙로 3가']
    chuncheon = pd.concat([chuncheon,step_chuncheon_data])
display(chuncheon)
chuncheon.to_excel("2011미세먼지.xlsx")
# Out:
#             지역 측정소명   측정소코드        측정일시    SO2   CO     O3    NO2 PM10             주소
# 232168  강원 춘천시  중앙로  132112  2011010101  0.007  1.1  0.002  0.040   61  강원 춘천시 중앙로 3가
# 232169  강원 춘천시  중앙로  132112  2011010102  0.007  1.3  0.002  0.039   68  강원 춘천시 중앙로 3가
# 232170  강원 춘천시  중앙로  132112  2011010103  0.006  1.1  0.002  0.038   65  강원 춘천시 중앙로 3가
# 232171  강원 춘천시  중앙로  132112  2011010104  0.006  1.0  0.003  0.034   53  강원 춘천시 중앙로 3가
# 232172  강원 춘천시  중앙로  132112  2011010105  0.007  1.0  0.003  0.034   54  강원 춘천시 중앙로 3가
# ...        ...  ...     ...         ...    ...  ...    ...    ...  ...            ...
# 249499  강원 춘천시  중앙로  132112  2011123120  0.006  1.2  0.002  0.042  118  강원 춘천시 중앙로 3가
# 249500  강원 춘천시  중앙로  132112  2011123121  0.006  1.2  0.002  0.042  144  강원 춘천시 중앙로 3가
# 249501  강원 춘천시  중앙로  132112  2011123122  0.008  1.5  0.003  0.045  139  강원 춘천시 중앙로 3가
# 249502  강원 춘천시  중앙로  132112  2011123123  0.008  1.6  0.003  0.045  141  강원 춘천시 중앙로 3가
# ...

# %%
import os
dr = os.listdir("./2012")
chuncheon = pd.DataFrame(columns=['지역', '측정소명', '측정소코드', '측정일시', 'SO2', 'CO', 'O3', 'NO2', 'PM10', '주소'])
chuncheon.columns = data.columns
for file_name in dr:
    file_name = './2012/' + file_name
    data = pd.read_excel(file_name)
    step_chuncheon_data = data[data["주소"] == '강원 춘천시 중앙로 3가']
    chuncheon = pd.concat([chuncheon,step_chuncheon_data])
display(chuncheon)
chuncheon.to_excel("2012미세먼지.xlsx")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-31486616104d> in <module>
#       2 dr = os.listdir("./2012")
#       3 chuncheon = pd.DataFrame(columns=['지역', '측정소명', '측정소코드', '측정일시', 'SO2', 'CO', 'O3', 'NO2', 'PM10', '주소'])
# ----> 4 chuncheon.columns = data.columns
#       5 for file_name in dr:
#       6     file_name = './2012/' + file_name
#
# NameError: name 'data' is not defined

# %%
import os
dr = os.listdir("./2013")
chuncheon = pd.DataFrame(columns=['지역', '측정소명', '측정소코드', '측정일시', 'SO2', 'CO', 'O3', 'NO2', 'PM10', '주소'])
chuncheon.columns = data.columns
for file_name in dr:
    file_name = './2013/' + file_name
    data = pd.read_excel(file_name)
    step_chuncheon_data = data[data["주소"] == '강원 춘천시 중앙로 3가']
    chuncheon = pd.concat([chuncheon,step_chuncheon_data])
display(chuncheon)
chuncheon.to_excel("2013미세먼지.xlsx")
# Out:
#             지역 측정소명   측정소코드        측정일시    SO2   CO     O3    NO2 PM10             주소
# 245496  강원 춘천시  중앙로  132112  2013010101  0.004  1.0  0.016  0.017   25  강원 춘천시 중앙로 3가
# 245497  강원 춘천시  중앙로  132112  2013010102  0.006  1.3  0.006  0.029   43  강원 춘천시 중앙로 3가
# 245498  강원 춘천시  중앙로  132112  2013010103  0.007  1.5  0.002  0.035   38  강원 춘천시 중앙로 3가
# 245499  강원 춘천시  중앙로  132112  2013010104  0.006  1.3  0.005  0.030   40  강원 춘천시 중앙로 3가
# 245500  강원 춘천시  중앙로  132112  2013010105  0.007  1.5  0.002  0.033   39  강원 춘천시 중앙로 3가
# ...        ...  ...     ...         ...    ...  ...    ...    ...  ...            ...
# 256123  강원 춘천시  중앙로  132112  2013123120  0.016  0.8  0.022  0.019  129  강원 춘천시 중앙로 3가
# 256124  강원 춘천시  중앙로  132112  2013123121  0.017  0.9  0.018  0.021  129  강원 춘천시 중앙로 3가
# 256125  강원 춘천시  중앙로  132112  2013123122  0.019  0.9  0.018  0.020  135  강원 춘천시 중앙로 3가
# 256126  강원 춘천시  중앙로  132112  2013123123  0.019  0.8  0.019  0.017  148  강원 춘천시 중앙로 3가
# ...

# %%
import os
dr = os.listdir("./2014")
chuncheon = pd.DataFrame(columns=['지역', '측정소명', '측정소코드', '측정일시', 'SO2', 'CO', 'O3', 'NO2', 'PM10', '주소'])
chuncheon.columns = data.columns
for file_name in dr:
    file_name = './2014/' + file_name
    data = pd.read_csv(file_name,encoding='cp949')
    step_chuncheon_data = data[data["주소"] == '강원 춘천시 중앙로 3가']
    chuncheon = pd.concat([chuncheon,step_chuncheon_data])
display(chuncheon)
chuncheon.to_excel("2014미세먼지.xlsx")
# Out:
# c:\python\venv\tensorflow\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   if __name__ == '__main__':
#         CO    NO2     O3   PM10  PM25    SO2             주소      지역 측정소명   측정소코드        측정일시
# 17280  0.8  0.010  0.026  161.0   NaN  0.011  강원 춘천시 중앙로 3가  강원 춘천시  중앙로  132112  2014010101
# 17281  0.9  0.012  0.023  145.0   NaN  0.011  강원 춘천시 중앙로 3가  강원 춘천시  중앙로  132112  2014010102
# 17282  1.0  0.016  0.017  154.0   NaN  0.012  강원 춘천시 중앙로 3가  강원 춘천시  중앙로  132112  2014010103
# 17283  1.1  0.017  0.014  146.0   NaN  0.012  강원 춘천시 중앙로 3가  강원 춘천시  중앙로  132112  2014010104
# 17284  1.1  0.016  0.013  146.0   NaN  0.012  강원 춘천시 중앙로 3가  강원 춘천시  중앙로  132112  2014010105
# ...

# %%
import os
dr = os.listdir("./2015")
chuncheon = pd.DataFrame(columns=['지역', '측정소명', '측정소코드', '측정일시', 'SO2', 'CO', 'O3', 'NO2', 'PM10', '주소'])
for file_name in dr:
    file_name = './2015/' + file_name
    data = pd.read_csv(file_name)
    step_chuncheon_data = data[data["주소"] == '강원 춘천시 중앙로 3가 67-1(춘천시보건소 3층 옥상)']
    chuncheon = pd.concat([chuncheon,step_chuncheon_data])
display(chuncheon)
chuncheon.to_excel("2015미세먼지.xlsx")
# Out:
# c:\python\venv\tensorflow\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#         CO    NO2     O3  PM10  PM25    SO2                                주소      지역 측정소명   측정소코드        측정일시
# 17280  0.4  0.008  0.022  40.0  10.0  0.006  강원 춘천시 중앙로 3가 67-1(춘천시보건소 3층 옥상)  강원 춘천시  중앙로  132112  2015010101
# 17281  0.4  0.008  0.021  57.0  13.0  0.006  강원 춘천시 중앙로 3가 67-1(춘천시보건소 3층 옥상)  강원 춘천시  중앙로  132112  2015010102
# 17282  0.4  0.007  0.022  62.0  12.0  0.006  강원 춘천시 중앙로 3가 67-1(춘천시보건소 3층 옥상)  강원 춘천시  중앙로  132112  2015010103
# 17283  0.4  0.007  0.021  60.0  12.0  0.005  강원 춘천시 중앙로 3가 67-1(춘천시보건소 3층 옥상)  강원 춘천시  중앙로  132112  2015010104
# ...

# %%
import os
dr = os.listdir("./2016")
chuncheon = pd.DataFrame(columns=['지역', '측정소명', '측정소코드', '측정일시', 'SO2', 'CO', 'O3', 'NO2', 'PM10', '주소'])
for file_name in dr:
    file_name = './2016/' + file_name
    data = pd.read_csv(file_name,encoding='cp949')
    step_chuncheon_data = data[data["주소"] == '강원 춘천시 중앙로 3가']
    chuncheon = pd.concat([chuncheon,step_chuncheon_data])
display(chuncheon)
chuncheon.to_excel("2016미세먼지.xlsx")
# Out:
# c:\python\venv\tensorflow\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#         CO    NO2     O3  PM10  PM25    SO2             주소      지역 측정소명  \
# 17472  1.8  0.028  0.004  92.0  59.0  0.006  강원 춘천시 중앙로 3가  강원 춘천시  중앙로
# 17473  1.5  0.020  0.006  96.0  65.0  0.004  강원 춘천시 중앙로 3가  강원 춘천시  중앙로
# 17474  1.8  0.030  0.002  96.0  62.0  0.005  강원 춘천시 중앙로 3가  강원 춘천시  중앙로
# 17475  1.6  0.024  0.003  92.0  72.0  0.005  강원 춘천시 중앙로 3가  강원 춘천시  중앙로
# 17476  1.6  0.023  0.002  81.0  71.0  0.006  강원 춘천시 중앙로 3가  강원 춘천시  중앙로
# ...    ...    ...    ...   ...   ...    ...            ...     ...  ...
# 19867  1.1  0.040  0.004  87.0  46.0  0.006  강원 춘천시 중앙로 3가  강원 춘천시  중앙로
# ...

# %%
import os
dr = os.listdir("./2017")
chuncheon = pd.DataFrame(columns=['지역', '측정소명', '측정소코드', '측정일시', 'SO2', 'CO', 'O3', 'NO2', 'PM10', '주소'])
for file_name in dr:
    file_name = './2017/' + file_name
    data = pd.read_excel(file_name)
    loc = list(set(data.loc[:,'주소'].to_list()))
    if '강원 춘천시 중앙로 3가 67-1(춘천시보건소 3층 옥상)' in loc:
        step_chuncheon_data = data[data["주소"] == '강원 춘천시 중앙로 3가 67-1(춘천시보건소 3층 옥상)']
    elif '강원 춘천시 중앙로길 135(중앙로 3가 67-1)' in loc:
        step_chuncheon_data = data[data["주소"] == '강원 춘천시 중앙로길 135(중앙로 3가 67-1)']
    chuncheon = pd.concat([chuncheon,step_chuncheon_data])
display(chuncheon)
chuncheon.to_excel("2017미세먼지.xlsx")
# Out:
# c:\python\venv\tensorflow\lib\site-packages\ipykernel_launcher.py:12: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   if sys.path[0] == '':
#          CO    NO2     O3  PM10  PM25    SO2  \
# 250560  1.1  0.022  0.004  74.0  54.0  0.004
# 250561  1.1  0.024  0.002  75.0  55.0  0.005
# 250562  1.0  0.018  0.003  68.0  59.0  0.004
# 250563  1.0  0.020  0.002  65.0  57.0  0.004
# 250564  1.1  0.018  0.002  62.0  56.0  0.005
# ...     ...    ...    ...   ...   ...    ...
# 753592  NaN  0.023  0.023  37.0  17.0  0.003
# 753593  NaN  0.013  0.028  37.0  16.0  0.003
# 753594  NaN  0.016  0.025  33.0  16.0  0.003
# 753595  NaN  0.015  0.025  27.0  13.0  0.003
# 753596  NaN  0.013  0.026  25.0   8.0  0.003
#
# ...

# %%
import os
dr = os.listdir("./2018")
chuncheon = pd.DataFrame(columns=['지역', '측정소명', '측정소코드', '측정일시', 'SO2', 'CO', 'O3', 'NO2', 'PM10', '주소'])
for file_name in dr:
    file_name = './2018/' + file_name
    data = pd.read_excel(file_name)
    step_chuncheon_data = data[data["주소"] == '강원 춘천시 중앙로길 135(중앙로 3가 67-1)']
    chuncheon = pd.concat([chuncheon,step_chuncheon_data])
display(chuncheon)
chuncheon.to_excel("2018미세먼지.xlsx")
# Out:
# c:\python\venv\tensorflow\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#          CO    NO2     O3  PM10  PM25    SO2     망                            주소      지역 측정소명   측정소코드        측정일시
# 257040  NaN  0.038  0.008  35.0   7.0  0.005   NaN  강원 춘천시 중앙로길 135(중앙로 3가 67-1)  강원 춘천시  중앙로  132112  2018010101
# 257041  NaN  0.040  0.006  41.0  23.0  0.004   NaN  강원 춘천시 중앙로길 135(중앙로 3가 67-1)  강원 춘천시  중앙로  132112  2018010102
# 257042  NaN  0.042  0.004  42.0  20.0  0.004   NaN  강원 춘천시 중앙로길 135(중앙로 3가 67-1)  강원 춘천시  중앙로  132112  2018010103
# 257043  NaN  0.025  0.010  40.0  18.0  0.003   NaN  강원 춘천시 중앙로길 135(중앙로 3가 67-1)  강원 춘천시  중앙로  132112  2018010104
# ...

# %%
import os
dr = os.listdir("./2019")
chuncheon = pd.DataFrame(columns=['지역', '측정소명', '측정소코드', '측정일시', 'SO2', 'CO', 'O3', 'NO2', 'PM10', '주소'])
for file_name in dr:
    file_name = './2019/' + file_name
    data = pd.read_excel(file_name)
    step_chuncheon_data = data[data["주소"] == '강원 춘천시 중앙로길 135(중앙로 3가 67-1)']
    chuncheon = pd.concat([chuncheon,step_chuncheon_data])
display(chuncheon)
chuncheon.to_excel("2019미세먼지.xlsx")
# Out:
# c:\python\venv\tensorflow\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#          CO    NO2     O3 PM10 PM25    SO2     망                            주소      지역 측정소명   측정소코드        측정일시
# 121667  1.3  0.044  0.002   72   37  0.004  도시대기  강원 춘천시 중앙로길 135(중앙로 3가 67-1)  강원 춘천시  중앙로  132112  2019010101
# 121668    1  0.034  0.002   58   39  0.004  도시대기  강원 춘천시 중앙로길 135(중앙로 3가 67-1)  강원 춘천시  중앙로  132112  2019010102
# 121669  1.1  0.044  0.002   63   34  0.004  도시대기  강원 춘천시 중앙로길 135(중앙로 3가 67-1)  강원 춘천시  중앙로  132112  2019010103
# 121670  1.1  0.042  0.002   52  NaN  0.004  도시대기  강원 춘천시 중앙로길 135(중앙로 3가 67-1)  강원 춘천시  중앙로  132112  2019010104
# ...

# %%
input_data = pd.read_csv("20191122210552.csv",encoding = 'utf8')
